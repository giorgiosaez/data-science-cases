# %% [markdown]
# # 3.Marketing_Case-ELVT-Deploy

# %% [markdown]
# In this 3rd and last notebook we will deploy our model into Azure Machine learning service

# %%
import sys

# !{sys.executable} -m pip install azureml-sdk
# Out:
# Collecting azureml-sdk
#   Downloading https://files.pythonhosted.org/packages/19/35/0977fded1b6d5be069449e2f1cdcb80480cfb17ebba1159be5ffa39db6dc/azureml_sdk-0.1.80-py3-none-any.whl
# Collecting azureml-train==0.1.80.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/9d/90/a042e5a7500c0daf5b5e2ae727fdecc19ee34ef17870bf05338fedf96f3b/azureml_train-0.1.80-py3-none-any.whl
# Collecting azureml-pipeline==0.1.80.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/18/07/a4bdb865f495967028761178b45278cccd8cef79f4b1a59d20c7c0553333/azureml_pipeline-0.1.80-py3-none-any.whl
# Collecting azureml-core==0.1.80.* (from azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e7/a3/8789ed59f632e027cc2ac9301cd78e36b6b0846c44722e96b340418f1468/azureml_core-0.1.80-py2.py3-none-any.whl (805kB)
# Collecting azureml-train-core==0.1.80.* (from azureml-train==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/c9/b8/8d1bf24b2d5f8e5a9ea7024fc3d9059c6de8796177df012f119f0f552e6c/azureml_train_core-0.1.80-py3-none-any.whl (62kB)
# Collecting azureml-pipeline-steps==0.1.80.* (from azureml-pipeline==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/d2/2f/aadfdeba8072b01d3dc3a822d7145930183b22a7d05f54aef2dc3f89505c/azureml_pipeline_steps-0.1.80-py3-none-any.whl
# Collecting azureml-pipeline-core==0.1.80.* (from azureml-pipeline==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/87/cd/d492c921a92f9118081312e5e431b2c91b3e12f8b85673c30a52b3cd9762/azureml_pipeline_core-0.1.80-py3-none-any.whl (112kB)
# Collecting PyJWT (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/93/d1/3378cc8184a6524dc92993090ee8b4c03847c567e298305d6cf86987e005/PyJWT-1.6.4-py2.py3-none-any.whl
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/35/d1/e8887811e8e5ab336e77db7cfb9f451bdae69a8ed97f53cc2cd11fdcac8f/azure_mgmt_containerregistry-2.4.0-py2.py3-none-any.whl (482kB)
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ba/f6/054ace7b01c6c21b3b95a83c3997f7d6539d939a2c08c4f27f779128a030/azure_storage_nspkg-3.1.0-py2.py3-none-any.whl
# Requirement already satisfied: docker in c:\users\gsaez\appdata\roaming\python\python36\site-packages (from azureml-core==0.1.80.*->azureml-sdk) (3.5.1)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/73/84/025ac436a6a1d5516d1a67887d7122b3b2ea04ba6b2d2c46fe949accb62b/azure_storage_common-1.4.0-py2.py3-none-any.whl (46kB)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
# Collecting requests>=2.19.1 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ff/17/5cbb026005115301a8fb2f9b0e3e8d32313142fe8b617070e7baad20554f/requests-2.20.1-py2.py3-none-any.whl (57kB)
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/2b/26/c0cb69dfac2e5b7125db034045b8bcf937cf1e8d3df2009a87c33d0959f5/azure_mgmt_resource-2.0.0-py2.py3-none-any.whl (698kB)
# Collecting pathspec (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting msrest>=0.5.1 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/d5/40/70e545b7a5b0509273c6fe981118fb64e389fe013504b1c22a24fec4d1d9/msrest-0.6.2-py2.py3-none-any.whl (81kB)
# Requirement already satisfied: contextlib2 in c:\programdata\anaconda3\lib\site-packages (from azureml-core==0.1.80.*->azureml-sdk) (0.5.5)
# Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from azureml-core==0.1.80.*->azureml-sdk) (1.11.0)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e8/d9/496b29857a252bc3fcc4bbda069c0eb64b537c8e8f7e342abb4053ba920f/azure_mgmt_storage-3.1.0-py2.py3-none-any.whl (696kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/c2/d3/fdc722a1b61857250a76027d6d73a50182c6d85132ddd65600a8993574ce/azure_cli_profile-2.1.2-py2.py3-none-any.whl
# Collecting urllib3<1.24,>=1.23 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting azure-cli-core>=2.0.38 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e3/1c/fc8f83c01a47d32a49753e98a30712ee2c0a8fbbbd6ec5fd1a89e31d4846/azure_cli_core-2.0.51-py2.py3-none-any.whl (107kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/29/23/7d46d24c504abadd25300ec847cc0a8be3499ba14b0586492b014988c0fc/ruamel.yaml-0.15.51-cp36-cp36m-win_amd64.whl (207kB)
# Collecting backports.tempfile (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
# Collecting msrestazure>=0.4.33 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/62/6e/c41d6e2db39f4c6b819cea5b47c36c0fa0e7a931cd39b4c5f19713d28fd1/msrestazure-0.5.1-py2.py3-none-any.whl
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/3c/a5/ac7f4d9fa22cf6783e2d62cbfdf0b14b937d873a9d129f8d4d95e2184af5/cryptography-2.4.2-cp36-cp36m-win_amd64.whl (1.3MB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting ndg-httpsclient (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from azureml-core==0.1.80.*->azureml-sdk) (2017.2)
# Collecting jsonpickle (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ca/ce/97404d5aeb58e6155c216825c81b50f6eca8a5345c582317ae48391878f8/jsonpickle-1.0-py2.py3-none-any.whl
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/f7/b7/9b20c39bf411e896d110d01f2551e6e7b397fde6eb06b07293fe29705d13/azure_storage_blob-1.4.0-py2.py3-none-any.whl (75kB)
# Collecting SecretStorage<3.0.0 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting python-dateutil>=2.7.3 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/74/68/d87d9b36af36f44254a8d512cbfc48369103a3b9e474be9bdfe536abfc45/python_dateutil-2.7.5-py2.py3-none-any.whl (225kB)
# Collecting azure-common>=1.1.12 (from azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/ac/d3/055ce7ad06459a415ff9ca210e04c6cbb51bd6564815b7c8ac34bf5a1c39/azure_common-1.1.16-py2.py3-none-any.whl
# Collecting azureml-train-restclients-hyperdrive==0.1.80.* (from azureml-train-core==0.1.80.*->azureml-train==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/2d/f4/4190fcf805b0ec7fb809e1a089d7562f98451435ab3e7a4271b3f8f5ba31/azureml_train_restclients_hyperdrive-0.1.80-py3-none-any.whl
# Collecting azureml-telemetry==0.1.80.* (from azureml-train-core==0.1.80.*->azureml-train==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/f2/9e/fb6c4e5a9b183e8a85562d15a4419ba077832a4551895c940cab89396202/azureml_telemetry-0.1.80-py3-none-any.whl
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from azureml-pipeline-steps==0.1.80.*->azureml-pipeline==0.1.80.*->azureml-sdk) (2017.7.27.1)
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Requirement already satisfied: pypiwin32==223; sys_platform == "win32" and python_version >= "3.6" in c:\users\gsaez\appdata\roaming\python\python36\site-packages (from docker->azureml-core==0.1.80.*->azureml-sdk) (223)
# Requirement already satisfied: docker-pycreds>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from docker->azureml-core==0.1.80.*->azureml-sdk) (0.3.0)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from docker->azureml-core==0.1.80.*->azureml-sdk) (0.54.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.1->azureml-core==0.1.80.*->azureml-sdk) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.1->azureml-core==0.1.80.*->azureml-sdk) (2.6)
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-resource>=1.2.1->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.1->azureml-core==0.1.80.*->azureml-sdk) (1.0.0)
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Requirement already satisfied: colorama>=0.3.9 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk) (0.3.9)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/79/1e/13d96248e3fcaa7777b61fa889feab44865c85e524bbd667acfa0d8b66e3/humanfriendly-4.17-py2.py3-none-any.whl (72kB)
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting knack==0.4.5 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/02/89/1ea05831b95d6bdc8880acdd0304a915156eb5f94aeab0fd36649a940c45/knack-0.4.5-py2.py3-none-any.whl (49kB)
# Collecting adal>=1.2.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/2d/2f/14882b8dae0977e85577abde3065c141fb94dbb242adfb80e21797e4f7c9/adal-1.2.0-py2.py3-none-any.whl (52kB)
# Requirement already satisfied: tabulate<=0.8.2,>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk) (0.8.2)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk) (2.2.0)
# Collecting pyyaml~=3.13 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/4f/ca/5fad249c5032270540c24d2189b0ddf1396aac49b0bdc548162edcf14131/PyYAML-3.13-cp36-cp36m-win_amd64.whl (206kB)
# Collecting antlr4-python3-runtime; python_version >= "3.0" (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/3e/96/aba01b2948ec67f237cd387c022820835ae0d8db5cab4bd404b351660b5e/antlr4-python3-runtime-4.7.1.tar.gz (111kB)
# Requirement already satisfied: pyopenssl>=17.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk) (17.2.0)
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Requirement already satisfied: pip in c:\users\gsaez\appdata\roaming\python\python36\site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk) (18.1)
# Collecting backports.weakref (from backports.tempfile->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in c:\programdata\anaconda3\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==0.1.80.*->azureml-sdk) (1.10.0)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==0.1.80.*->azureml-sdk) (0.22.0)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/d1/a1/7790cc85db38daa874f6a2e6308131b9953feb1367f2ae2d1123bb93a9f5/pyasn1-0.4.4-py2.py3-none-any.whl (72kB)
# Collecting applicationinsights (from azureml-telemetry==0.1.80.*->azureml-train-core==0.1.80.*->azureml-train==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Requirement already satisfied: pywin32>=223 in c:\users\gsaez\appdata\roaming\python\python36\site-packages (from pypiwin32==223; sys_platform == "win32" and python_version >= "3.6"->docker->azureml-core==0.1.80.*->azureml-sdk) (224)
# Requirement already satisfied: oauthlib>=0.6.2 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==0.1.80.*->azureml-sdk) (2.1.0)
# Collecting pyreadline; sys_platform == "win32" (from humanfriendly>=4.7->azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/bc/7c/d724ef1ec3ab2125f38a1d53285745445ec4a8f19b9bb0761b4064316679/pyreadline-2.1.zip (109kB)
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/b5/0f/5f21bd04c8f45685c7b72013fc8efaf0e25baf3b77e62b3b915b5b43a7b6/PyNaCl-1.3.0-cp36-cp36m-win_amd64.whl (188kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/4b/c0/c0550e4b98e0536d3a8b8753b68aa0d3c03af654c43a58328d0bf2c06747/bcrypt-3.1.4-cp36-cp36m-win_amd64.whl
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==0.1.80.*->azureml-sdk)
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==0.1.80.*->azureml-sdk) (2.18)
# Building wheels for collected packages: pathspec, SecretStorage, antlr4-python3-runtime, pyreadline
#   Running setup.py bdist_wheel for pathspec: started
#   Running setup.py bdist_wheel for pathspec: finished with status 'done'
#   Stored in directory: C:\Users\gsaez\AppData\Local\pip\Cache\wheels\45\cb\7e\ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Running setup.py bdist_wheel for SecretStorage: started
#   Running setup.py bdist_wheel for SecretStorage: finished with status 'done'
#   Stored in directory: C:\Users\gsaez\AppData\Local\pip\Cache\wheels\4e\5b\1b\be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Running setup.py bdist_wheel for antlr4-python3-runtime: started
#   Running setup.py bdist_wheel for antlr4-python3-runtime: finished with status 'done'
#   Stored in directory: C:\Users\gsaez\AppData\Local\pip\Cache\wheels\ef\f6\18\ad300e691236a3408a99edc750484b56e8d6b11b2c38eacb10
#   Running setup.py bdist_wheel for pyreadline: started
#   Running setup.py bdist_wheel for pyreadline: finished with status 'done'
#   Stored in directory: C:\Users\gsaez\AppData\Local\pip\Cache\wheels\70\66\59\590265c96902c7616243300c8f0d8ffe7800253ad55dfa9aa1
# Successfully built pathspec SecretStorage antlr4-python3-runtime pyreadline
# Installing collected packages: python-dateutil, urllib3, azureml-train-restclients-hyperdrive, PyJWT, requests, isodate, msrest, cryptography, adal, msrestazure, azure-common, azure-mgmt-containerregistry, azure-nspkg, azure-storage-nspkg, azure-storage-common, azure-graphrbac, azure-mgmt-nspkg, azure-mgmt-resource, pathspec, azure-mgmt-storage, azure-cli-nspkg, azure-cli-command-modules-nspkg, argcomplete, pyreadline, humanfriendly, jmespath, pyyaml, knack, antlr4-python3-runtime, wheel, pynacl, pyasn1, bcrypt, paramiko, portalocker, applicationinsights, azure-cli-telemetry, azure-cli-core, azure-cli-profile, ruamel.yaml, backports.weakref, backports.tempfile, azure-mgmt-authorization, azure-mgmt-keyvault, ndg-httpsclient, jsonpickle, azure-storage-blob, SecretStorage, azureml-core, azureml-telemetry, azureml-train-core, azureml-train, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
#   Found existing installation: python-dateutil 2.6.1
#     Uninstalling python-dateutil-2.6.1:
# Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\dateutil\\easter.py'
# Consider using the `--user` option or check the permissions.

# %%
import pickle

# %%
TEST_DF_FILE = 'marketing_test.pkl'
MODEL_FILE = 'marketing_model'

# %%
with open(TEST_DF_FILE, 'rb') as handle:
    test = pickle.load(handle)
test
# Out:
#    cons.conf.idx  cons.price.idx    contact day_of_week default  emp.var.rate  \
# 0          -47.1          93.075  telephone         wed      no          -1.8
#
#    euribor3m housing loan  marital         ...          nr.employed  \
# 0      1.415      no   no  married         ...               5099.1
#
#       poutcome  profession responded          schooling campaign1  custAge1  \
# 0  nonexistent  management        no  university.degree         4        42
#
#    pastEmail1 pcontacted_pdays  pContacted_previous
# 0          no             True                   no
#
# [1 rows x 21 columns]
